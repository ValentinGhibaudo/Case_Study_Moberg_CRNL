# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as np
import physio # Toolbox made in Lyon, CRNL, France, for processing ECG and Respiratory signals
from configuration import *

from pycns import CnsReader, get_viewer # Toolbox made in Lyon, CRNL, France, for reading and viewing Moberg raw data

from physio_rea_analyse import * # Tools for computing binarized Heart / Resp rate variability
from custom_view import * # Tools for plotting 2D representations of Heart / Resp rate variability and others ...
from tools import * # useful tools

# %% [markdown]
# - pycns : https://github.com/samuelgarcia/pycns
# - physio : https://github.com/samuelgarcia/physio

# %% [markdown]
# # Patient ID selection

# %%
patient_id = 'MF12'

# %% [markdown]
# # Metadata

# %%
meta = get_metadata(patient_id)
meta
# Out:
# sex                                              F
# ddn                            1953-12-10 00:00:00
# age                            1968-09-28 00:00:00
# motif                                          HSA
# entree_rea                     2022-09-08 00:00:00
# debut_monito                   2022-09-09 00:00:00
# fin_monito                     2022-09-15 00:00:00
# durée                                          6.0
# EEG                                            1.0
# ECoG                                         strip
# ptio2                                          0.0
# PIC                                            1.0
# NIRS                                           1.0
# event_during_monito                            NaN
# commentaire            SD; mort encephalique & NUP
# Name: MF12, dtype: object

# %% [markdown]
# # Events

# %%
events = read_events(patient_id)
events['StartTimeGMT'] = pd.to_datetime(events['StartTime']).dt.tz_localize('Europe/Paris').dt.tz_convert('GMT')
events.head(10)
# Out:
#             Name Description                StartTime Duration      Target
# 0             SD        None  2022-09-09 23:56:32.490   3806.2  EEG,Trends  \
# 1  2:mydriase dt        None  2022-09-10 06:00:56.000        0      Trends
# 2     1:propofol        None  2022-09-10 06:24:46.233        0      Trends
# 3            TDM        None  2022-09-10 07:56:50.279   2040.6  EEG,Trends
# 4             SD        None  2022-09-10 14:34:24.651      872  EEG,Trends
# 5             SD        None  2022-09-10 16:48:16.812    571.7  EEG,Trends
# 6             SD        None  2022-09-10 18:50:23.445    582.5  EEG,Trends
# 7             SD        None  2022-09-10 20:25:40.028  513.799  EEG,Trends
# 8             SD        None  2022-09-10 21:24:27.666    658.5  EEG,Trends
# 9             SD        None  2022-09-10 22:13:13.495    705.5  EEG,Trends
#
#                               EventDisplay Source
# 0    {'@color': '#99ff99', '#text': 'Box'}   User  \
# 1   {'@color': '#8080ff', '#text': 'Line'}    CNS
# 2   {'@color': '#8080ff', '#text': 'Line'}    CNS
# 3  {'@color': '#000000', '#text': 'Shade'}   User
# 4    {'@color': '#99ff99', '#text': 'Box'}   User
# 5    {'@color': '#99ff99', '#text': 'Box'}   User
# 6    {'@color': '#99ff99', '#text': 'Box'}   User
# 7    {'@color': '#99ff99', '#text': 'Box'}   User
# 8    {'@color': '#99ff99', '#text': 'Box'}   User
# 9    {'@color': '#99ff99', '#text': 'Box'}   User
#
#                       StartTimeGMT
# 0 2022-09-09 21:56:32.490000+00:00
# 1        2022-09-10 04:00:56+00:00
# 2 2022-09-10 04:24:46.233000+00:00
# 3 2022-09-10 05:56:50.279000+00:00
# 4 2022-09-10 12:34:24.651000+00:00
# 5 2022-09-10 14:48:16.812000+00:00
# 6 2022-09-10 16:50:23.445000+00:00
# 7 2022-09-10 18:25:40.028000+00:00
# 8 2022-09-10 19:24:27.666000+00:00
# 9 2022-09-10 20:13:13.495000+00:00

# %% [markdown]
# # Preload data

# %%
path_to_data = data_path / patient_id # path to raw data
reader = CnsReader(path_to_data) # preload raw data

# %%
reader
# Out:
# CnsReader: MF12
# 17 streams : ['SpO2', 'CPP', 'ICP', 'EEG_NeonatalParams', 'ABP_Syst', 'HR', 'ECG_II', 'ABP', 'CO2', 'ABP_Mean', 'EEG', 'EEG_Impedance', 'Temp', 'EtCO2_Ext', 'ABP_Dias', 'PLETH', 'ICP_Mean']

# %% [markdown]
# # Detect ECG Peaks

# %%
ecg_stream = reader.streams['ECG_II']
srate_ecg = ecg_stream.sample_rate

start_date = None # from beginning
stop_date = None # to the end

ecg_raw, ecg_dates = ecg_stream.get_data(sel = slice(start_date,stop_date), with_times=True, apply_gain=False)
ecg, r_peaks = physio.compute_ecg(ecg_raw, srate_ecg, parameter_preset = 'human_ecg')
r_peaks['peak_date'] = ecg_dates[r_peaks['peak_index']]

# %%
r_peaks
# Out:
#         peak_index      peak_time                  peak_date
# 0              164       0.328151 2022-09-09 17:16:04.809318
# 1              696       1.392639 2022-09-09 17:16:05.873776
# 2             1265       2.531162 2022-09-09 17:16:07.012265
# 3             1822       3.645674 2022-09-09 17:16:08.126743
# 4             2378       4.758185 2022-09-09 17:16:09.239221
# ...            ...            ...                        ...
# 514422   240161750  480544.165000 2022-09-15 07:17:07.974409
# 514423   240162146  480544.957364 2022-09-15 07:17:08.766771
# 514424   240162542  480545.749728 2022-09-15 07:17:09.559133
# 514425   240162937  480546.540091 2022-09-15 07:17:10.349494
# 514426   240163333  480547.332455 2022-09-15 07:17:11.141856
#
# [514427 rows x 3 columns]

# %% [markdown]
# # Detect Respiratory Cycles

# %%
co2_stream = reader.streams['CO2']
srate_co2 = co2_stream.sample_rate

start_date = None # from beginning
stop_date = None  # to the end

co2_raw, co2_dates = co2_stream.get_data(sel = slice(start_date,stop_date), with_times=True, apply_gain=False)

co2, resp_cycles = physio.compute_respiration(co2_raw, srate_co2, parameter_preset = 'human_co2')
resp_cycles['cycle_frequency_per_min'] = resp_cycles['cycle_freq'] * 60
resp_cycles['inspi_date'] = co2_dates[resp_cycles['inspi_index']]
resp_cycles['expi_date'] = co2_dates[resp_cycles['expi_index']]

# %%
resp_cycles
# Out:
#         inspi_index  expi_index  next_inspi_index     inspi_time
# 0               512         709              1140       4.181027  \
# 1              1140        1349              1775       9.309318
# 2              1775        1976              2399      14.494771
# 3              2399        2703              3124      19.590398
# 4              3124        3331              3747      25.510798
# ...             ...         ...               ...            ...
# 119543     59982606    59982761          59983109  489822.065279
# 119544     59983109    59983259          59983595  489826.172812
# 119545     59983595    59983749          59984109  489830.141521
# 119546     59984109    59984265          59984607  489834.338880
# 119547     59984607    59984756          59984862  489838.405582
#
#             expi_time  next_inspi_time  cycle_duration  inspi_duration
# 0            5.789743         9.309318        5.128291        1.608715  \
# 1           11.016026        14.494771        5.185453        1.706708
# 2           16.136151        19.590398        5.095627        1.641380
# 3           22.072883        25.510798        5.920400        2.482485
# 4           27.201174        30.598258        5.087461        1.690376
# ...               ...              ...             ...             ...
# 119543  489823.331020    489826.172812        4.107532        1.265741
# 119544  489827.397722    489830.141521        3.968709        1.224910
# 119545  489831.399095    489834.338880        4.197359        1.257575
# 119546  489835.612787    489838.405582        4.066702        1.273907
# 119547  489839.622326    489840.487930        2.082347        1.216744
#
#         expi_duration  cycle_freq  cycle_ratio  cycle_frequency_per_min
# 0            3.519575    0.194997     0.313694                11.699804  \
# 1            3.478745    0.192847     0.329134                11.570830
# 2            3.454247    0.196247     0.322115                11.774803
# 3            3.437915    0.168908     0.419310                10.134451
# 4            3.397084    0.196562     0.332263                11.793703
# ...               ...         ...          ...                      ...
# 119543       2.841792    0.243455     0.308151                14.607310
# 119544       2.743799    0.251971     0.308642                15.118265
# 119545       2.939785    0.238245     0.299611                14.294702
# 119546       2.792795    0.245899     0.313253                14.753970
# 119547       0.865603    0.480227     0.584314                28.813635
#
#                        inspi_date                  expi_date
# 0      2022-09-09 17:23:25.015960 2022-09-09 17:23:26.592637
# 1      2022-09-09 17:23:30.042118 2022-09-09 17:23:31.714837
# 2      2022-09-09 17:23:35.124301 2022-09-09 17:23:36.732992
# 3      2022-09-09 17:23:40.118446 2022-09-09 17:23:56.861637
# 4      2022-09-09 17:24:00.231085 2022-09-09 17:24:01.887796
# ...                           ...                        ...
# 119543 2022-09-15 07:16:53.283698 2022-09-15 07:16:54.524265
# 119544 2022-09-15 07:16:57.309537 2022-09-15 07:16:58.510086
# 119545 2022-09-15 07:17:01.199314 2022-09-15 07:17:02.431877
# 119546 2022-09-15 07:17:05.313193 2022-09-15 07:17:06.561764
# 119547 2022-09-15 07:17:09.299014 2022-09-15 07:17:10.491559
#
# [119548 rows x 14 columns]

# %% [markdown]
# # View quality of detections

# %%
# %matplotlib widget

ext_plots = [
            ECG_Detections(ecg_stream, r_peaks),
            Resp_Detections(co2_stream, resp_cycles),
            ]

w = get_viewer(reader, stream_names=['ECG_II'], ext_plots=ext_plots)
w
# Out:
# Viewer(children=(VBox(children=(HBox(children=(Button(description='autoscale', icon='refresh', style=ButtonSty…

# %% [markdown]
# # View Spreading Depolarizations + Heart Rate Features + Respi Rate features

# %%
# %matplotlib widget

rate_bins_resp = np.arange(5, 30, 0.5) # cpm resolution
step_bins_ecg = 1 # bpm resolution

window_size_mins = 3 # minutes

ext_plots = [
            Spreading_depol_bipol2(reader.streams['EEG'], detections = events),
            Spectrogram_eeg(reader.streams['EEG'], chan_name = 'ECoGA3-ECoGA2', wsize = 20, lf = 1, hf = 45),
            Respi_Rate(resp_cycles, resp_wsize_in_mins = window_size_mins, ratio_sat = 4, rate_bins_resp=rate_bins_resp),
            Heart_Rate(r_peaks, step_bins_ecg = step_bins_ecg, hrv_wsize_in_mins =window_size_mins, ratio_sat = 3),
            ]

w = get_viewer(reader, stream_names=['ECG_II'], ext_plots=ext_plots)
w
# Out:
# Viewer(children=(VBox(children=(HBox(children=(Button(description='autoscale', icon='refresh', style=ButtonSty…

# %%
# event_index = 10 # 2 SD + no variability
# event_index = 43 # 1 SD + variablity
event_index = 49 # NUP + tachycardia + loss of variability

win_jitter = np.timedelta64(20, 'm')
time_ev = np.datetime64(events.loc[event_index,'StartTimeGMT'])
new_time = time_ev - win_jitter

print(events.loc[event_index,'Name'])
print(time_ev)
print(events.loc[event_index,'Duration'])

w.time_slider.update_time(new_time=new_time)
# Out:
# /tmp/ipykernel_774228/447842486.py:6: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   time_ev = np.datetime64(events.loc[event_index,'StartTimeGMT'])
# NUP
# 2022-09-14T16:46:41.056000
# 52187.3

# %%
events
# Out:
#              Name Description                StartTime Duration      Target
# 0              SD        None  2022-09-09 23:56:32.490   3806.2  EEG,Trends  \
# 1   2:mydriase dt        None  2022-09-10 06:00:56.000        0      Trends
# 2      1:propofol        None  2022-09-10 06:24:46.233        0      Trends
# 3             TDM        None  2022-09-10 07:56:50.279   2040.6  EEG,Trends
# 4              SD        None  2022-09-10 14:34:24.651      872  EEG,Trends
# 5              SD        None  2022-09-10 16:48:16.812    571.7  EEG,Trends
# 6              SD        None  2022-09-10 18:50:23.445    582.5  EEG,Trends
# 7              SD        None  2022-09-10 20:25:40.028  513.799  EEG,Trends
# 8              SD        None  2022-09-10 21:24:27.666    658.5  EEG,Trends
# 9              SD        None  2022-09-10 22:13:13.495    705.5  EEG,Trends
# 10             SD        None  2022-09-10 23:11:35.807    730.9  EEG,Trends
# 11             SD        None  2022-09-11 00:23:46.661  814.098  EEG,Trends
# 12             SD        None  2022-09-11 02:21:32.790    817.7  EEG,Trends
# 13             SD        None  2022-09-11 03:44:45.755  806.799  EEG,Trends
# 14             SD        None  2022-09-11 04:44:45.755  937.098  EEG,Trends
# 15             SD        None  2022-09-11 05:17:10.780    940.7  EEG,Trends
# 16             SD        None  2022-09-11 06:34:58.117    915.4  EEG,Trends
# 17             SD        None  2022-09-11 07:26:31.584    817.7  EEG,Trends
# 18       SD + iSD        None  2022-09-11 07:43:37.614   4171.7  EEG,Trends
# 19             SD        None  2022-09-11 10:27:31.584    987.7  EEG,Trends
# 20             SD        None  2022-09-11 11:41:56.308     1592  EEG,Trends
# 21             SD        None  2022-09-11 13:32:06.559   1306.1  EEG,Trends
# 22             SD        None  2022-09-11 14:07:15.906   1324.2  EEG,Trends
# 23             SD        None  2022-09-11 14:45:58.720   1291.7  EEG,Trends
# 24             SD        None  2022-09-11 16:17:41.835   2583.3  EEG,Trends
# 25             SD        None  2022-09-11 17:47:00.227   1204.8  EEG,Trends
# 26             SD        None  2022-09-11 18:42:03.544   1476.2  EEG,Trends
# 27             SD        None  2022-09-11 19:48:48.770   1190.4  EEG,Trends
# 28             SD        None  2022-09-11 20:34:42.137     1516  EEG,Trends
# 29             SD        None  2022-09-11 22:21:58.720   1610.1  EEG,Trends
# 30             SD        None  2022-09-11 22:57:37.011   1693.3  EEG,Trends
# 31             SD        None  2022-09-12 00:32:06.559   1324.2  EEG,Trends
# 32             SD        None  2022-09-12 01:24:58.720   1233.8  EEG,Trends
# 33             SD        None  2022-09-12 03:57:50.579    980.5  EEG,Trends
# 34             SD        None  2022-09-12 05:43:18.619   1114.4  EEG,Trends
# 35             SD        None  2022-09-12 06:33:10.780     1317  EEG,Trends
# 36             SD        None  2022-09-12 09:14:54.499   1465.3  EEG,Trends
# 37             SD        None  2022-09-12 10:06:46.952   1754.8  EEG,Trends
# 38             SD        None  2022-09-12 11:07:56.598     1165  EEG,Trends
# 39             SD        None  2022-09-12 13:52:48.457   1038.4  EEG,Trends
# 40             SD        None  2022-09-12 15:48:26.145   1052.9  EEG,Trends
# 41     3:urapidil        None  2022-09-13 00:45:28.576        0      Trends
# 42             SD        None  2022-09-13 00:47:02.929   1324.2  EEG,Trends
# 43             SD        None  2022-09-13 05:18:06.246      872  EEG,Trends
# 44             SD        None  2022-09-13 08:44:52.678  850.299  EEG,Trends
# 45       artefact        None  2022-09-13 10:00:40.618   3408.2  EEG,Trends
# 46             SD        None  2022-09-13 15:39:55.995   1230.2  EEG,Trends
# 47             SD        None  2022-09-13 17:45:40.919   1754.8  EEG,Trends
# 48             SD        None  2022-09-14 16:10:31.573  752.598  EEG,Trends
# 49            NUP        None  2022-09-14 18:46:41.056  52187.3  EEG,Trends
# 50       artefact        None  2022-09-10 06:08:29.236  235.899  EEG,Trends
#
#                                EventDisplay Source
# 0     {'@color': '#99ff99', '#text': 'Box'}   User  \
# 1    {'@color': '#8080ff', '#text': 'Line'}    CNS
# 2    {'@color': '#8080ff', '#text': 'Line'}    CNS
# 3   {'@color': '#000000', '#text': 'Shade'}   User
# 4     {'@color': '#99ff99', '#text': 'Box'}   User
# 5     {'@color': '#99ff99', '#text': 'Box'}   User
# 6     {'@color': '#99ff99', '#text': 'Box'}   User
# 7     {'@color': '#99ff99', '#text': 'Box'}   User
# 8     {'@color': '#99ff99', '#text': 'Box'}   User
# 9     {'@color': '#99ff99', '#text': 'Box'}   User
# 10    {'@color': '#99ff99', '#text': 'Box'}   User
# 11    {'@color': '#99ff99', '#text': 'Box'}   User
# 12    {'@color': '#99ff99', '#text': 'Box'}   User
# 13    {'@color': '#99ff99', '#text': 'Box'}   User
# 14    {'@color': '#99ff99', '#text': 'Box'}   User
# 15    {'@color': '#99ff99', '#text': 'Box'}   User
# 16    {'@color': '#99ff99', '#text': 'Box'}   User
# 17    {'@color': '#99ff99', '#text': 'Box'}   User
# 18    {'@color': '#99ff99', '#text': 'Box'}   User
# 19    {'@color': '#99ff99', '#text': 'Box'}   User
# 20    {'@color': '#99ff99', '#text': 'Box'}   User
# 21    {'@color': '#99ff99', '#text': 'Box'}   User
# 22    {'@color': '#99ff99', '#text': 'Box'}   User
# 23    {'@color': '#99ff99', '#text': 'Box'}   User
# 24    {'@color': '#99ff99', '#text': 'Box'}   User
# 25    {'@color': '#99ff99', '#text': 'Box'}   User
# 26    {'@color': '#99ff99', '#text': 'Box'}   User
# 27    {'@color': '#99ff99', '#text': 'Box'}   User
# 28    {'@color': '#99ff99', '#text': 'Box'}   User
# 29    {'@color': '#99ff99', '#text': 'Box'}   User
# 30    {'@color': '#99ff99', '#text': 'Box'}   User
# 31    {'@color': '#99ff99', '#text': 'Box'}   User
# 32    {'@color': '#99ff99', '#text': 'Box'}   User
# 33    {'@color': '#99ff99', '#text': 'Box'}   User
# 34    {'@color': '#99ff99', '#text': 'Box'}   User
# 35    {'@color': '#99ff99', '#text': 'Box'}   User
# 36    {'@color': '#99ff99', '#text': 'Box'}   User
# 37    {'@color': '#99ff99', '#text': 'Box'}   User
# 38    {'@color': '#99ff99', '#text': 'Box'}   User
# 39    {'@color': '#99ff99', '#text': 'Box'}   User
# 40    {'@color': '#99ff99', '#text': 'Box'}   User
# 41   {'@color': '#8080ff', '#text': 'Line'}    CNS
# 42    {'@color': '#99ff99', '#text': 'Box'}   User
# 43    {'@color': '#99ff99', '#text': 'Box'}   User
# 44    {'@color': '#99ff99', '#text': 'Box'}   User
# 45  {'@color': '#aa0000', '#text': 'Shade'}   User
# 46    {'@color': '#99ff99', '#text': 'Box'}   User
# 47    {'@color': '#99ff99', '#text': 'Box'}   User
# 48    {'@color': '#99ff99', '#text': 'Box'}   User
# 49    {'@color': '#99ff99', '#text': 'Box'}   User
# 50    {'@color': '#aa0000', '#text': 'Box'}   User
#
#                        StartTimeGMT
# 0  2022-09-09 21:56:32.490000+00:00
# 1         2022-09-10 04:00:56+00:00
# 2  2022-09-10 04:24:46.233000+00:00
# 3  2022-09-10 05:56:50.279000+00:00
# 4  2022-09-10 12:34:24.651000+00:00
# 5  2022-09-10 14:48:16.812000+00:00
# 6  2022-09-10 16:50:23.445000+00:00
# 7  2022-09-10 18:25:40.028000+00:00
# 8  2022-09-10 19:24:27.666000+00:00
# 9  2022-09-10 20:13:13.495000+00:00
# 10 2022-09-10 21:11:35.807000+00:00
# 11 2022-09-10 22:23:46.661000+00:00
# 12 2022-09-11 00:21:32.790000+00:00
# 13 2022-09-11 01:44:45.755000+00:00
# 14 2022-09-11 02:44:45.755000+00:00
# 15 2022-09-11 03:17:10.780000+00:00
# 16 2022-09-11 04:34:58.117000+00:00
# 17 2022-09-11 05:26:31.584000+00:00
# 18 2022-09-11 05:43:37.614000+00:00
# 19 2022-09-11 08:27:31.584000+00:00
# 20 2022-09-11 09:41:56.308000+00:00
# 21 2022-09-11 11:32:06.559000+00:00
# 22 2022-09-11 12:07:15.906000+00:00
# 23 2022-09-11 12:45:58.720000+00:00
# 24 2022-09-11 14:17:41.835000+00:00
# 25 2022-09-11 15:47:00.227000+00:00
# 26 2022-09-11 16:42:03.544000+00:00
# 27 2022-09-11 17:48:48.770000+00:00
# 28 2022-09-11 18:34:42.137000+00:00
# 29 2022-09-11 20:21:58.720000+00:00
# 30 2022-09-11 20:57:37.011000+00:00
# 31 2022-09-11 22:32:06.559000+00:00
# 32 2022-09-11 23:24:58.720000+00:00
# 33 2022-09-12 01:57:50.579000+00:00
# 34 2022-09-12 03:43:18.619000+00:00
# 35 2022-09-12 04:33:10.780000+00:00
# 36 2022-09-12 07:14:54.499000+00:00
# 37 2022-09-12 08:06:46.952000+00:00
# 38 2022-09-12 09:07:56.598000+00:00
# 39 2022-09-12 11:52:48.457000+00:00
# 40 2022-09-12 13:48:26.145000+00:00
# 41 2022-09-12 22:45:28.576000+00:00
# 42 2022-09-12 22:47:02.929000+00:00
# 43 2022-09-13 03:18:06.246000+00:00
# 44 2022-09-13 06:44:52.678000+00:00
# 45 2022-09-13 08:00:40.618000+00:00
# 46 2022-09-13 13:39:55.995000+00:00
# 47 2022-09-13 15:45:40.919000+00:00
# 48 2022-09-14 14:10:31.573000+00:00
# 49 2022-09-14 16:46:41.056000+00:00
# 50 2022-09-10 04:08:29.236000+00:00
